# %% [markdown]
# <a href="https://colab.research.google.com/github/jonik2909/computer-vision/blob/main/data_scraping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install bing-image-downloader

# %%
from bing_image_downloader import downloader

# %%
downloader.download("uzbek pilaf plov food",
                    limit=100,
                    output_dir="/content/pilaf_images",
                    adult_filter_off=True,
                    force_replace=False,
                    timeout=60
                    )
# Out:
# [%] Downloading Images to /content/pilaf_images/uzbek pilaf plov food
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 35 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://thumbs.dreamstime.com/z/uzbek-cuisine-food-pilaf-plov-uzbek-cuisine-food-pilaf-plov-salad-achichuk-achuchuk-made-mutton-rice-carrots-vegetable-oil-205103317.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://thumbs.dreamstime.com/z/uzbek-cuisine-food-pilaf-plov-uzbek-cuisine-food-pilaf-plov-salad-achichuk-achuchuk-made-mutton-rice-carrots-vegetable-oil-205103463.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://thumbs.dreamstime.com/z/uzbek-cuisine-food-pilaf-plov-uzbek-cuisine-food-pilaf-plov-salad-achichuk-achuchuk-made-mutton-rice-carrots-vegetable-oil-205103447.jpg
# [%] File Downloaded !
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os, shutil

source_dir = '/content/pilaf_images/uzbek pilaf plov food'
target_dir = '/content/drive/MyDrive/food101_dataset/pilaf'

os.makedirs(target_dir, exist_ok=True)

for filename in os.listdir(source_dir):
  src_file = os.path.join(source_dir, filename)
  dst_file = os.path.join(target_dir, filename)
  shutil.move(src_file, dst_file)

# %%
downloader.download("kebab shashlik food",
                    limit=100,
                    output_dir="/content/kebab_images",
                    adult_filter_off=True,
                    force_replace=False,
                    timeout=60
                    )
# Out:
# Streaming output truncated to the last 5000 lines.
# [%] Indexed 22 Images on Page 2475.
#
# ...
#
#
#
# [!!]Indexing page: 2476
#
# [%] Indexed 22 Images on Page 2476.
#
# ...
#
#
#
# [!!]Indexing page: 2477
#
# [%] Indexed 22 Images on Page 2477.
#
# ...
#
#
#
# [!!]Indexing page: 2478
#
# [%] Indexed 22 Images on Page 2478.
#
# ...
#
#
#
# [!!]Indexing page: 2479
#
# [%] Indexed 22 Images on Page 2479.
#
# ...
#
#
#
# [!!]Indexing page: 2480
#
# [%] Indexed 22 Images on Page 2480.
#
# ...
#
#
#
# [!!]Indexing page: 2481
#
# [%] Indexed 22 Images on Page 2481.
#
# ...
#
#
#
# [!!]Indexing page: 2482
#
# [%] Indexed 22 Images on Page 2482.
#
# ...
#
#
#
# [!!]Indexing page: 2483
#
# [%] Indexed 22 Images on Page 2483.
#
# ...
#
#
#
# [!!]Indexing page: 2484
#
# [%] Indexed 22 Images on Page 2484.
#
# ...
#
#
#
# [!!]Indexing page: 2485
#
# [%] Indexed 22 Images on Page 2485.
#
# ...
#
#
#
# [!!]Indexing page: 2486
#
# [%] Indexed 22 Images on Page 2486.
#
# ...
#
#
#
# [!!]Indexing page: 2487
#
# [%] Indexed 22 Images on Page 2487.
#
# ...
#
#
#
# ...

# %%
import os, shutil

source_dir = '/content/kebab_images/kebab shashlik food'
target_dir = '/content/drive/MyDrive/food101_dataset/kebab'

os.makedirs(target_dir, exist_ok=True)

for filename in os.listdir(source_dir):
  src_file = os.path.join(source_dir, filename)
  dst_file = os.path.join(target_dir, filename)
  shutil.move(src_file, dst_file)
